# %% [markdown]
# # DL Assignment (Member - 02)

# %%
model_03 = None

# %% [markdown]
# ## Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import tensorflow as tf

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Data Pre Processing

# %% [markdown]
# 'fConc1' is inbetween 0 and 1

# %%
# Read the data as a dataframe
data_frame_original  = pd.read_csv('https://raw.githubusercontent.com/IT21034268/dl-assignment-2024/assignment-dataset/magic-gamma-telescope/gamma-telescope-data.csv')
data_frame_edited = data_frame_original

# %%
data_frame_edited.head()
# Out:
#     fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     fAlpha     fDist class
# 0  40.0920   81.8828     g
# 1   6.3609  205.2610     g
# 2  76.9600  256.7880     g
# 3  10.4490  116.7370     g
# 4   4.6480  356.4620     g

# %%
data_frame_edited = data_frame_edited.rename(columns={
                        'fLength': 'fLength_n',
                        'fWidth': 'fWidth_n',
                        'fSize': 'fSize_n',
                        'fConc': 'fConc_n',
                        'fAsym': 'fAsym_n',
                        'fM3Long': 'fM3Long_n',
                        'fM3Trans': 'fM3Trans_n',
                        'fAlpha': 'fAlpha_n',
                        'fDist': 'fDist_n'})

# %%
data_frame_edited.head()
# Out:
#    fLength_n  fWidth_n  fSize_n  fConc_n  fConc1   fAsym_n  fM3Long_n  \
# 0    28.7967   16.0021   2.6449   0.3918  0.1982   27.7004    22.0110
# 1    31.6036   11.7235   2.5185   0.5303  0.3773   26.2722    23.8238
# 2   162.0520  136.0310   4.0612   0.0374  0.0187  116.7410   -64.8580
# 3    23.8172    9.5728   2.3385   0.6147  0.3922   27.2107    -6.4633
# 4    75.1362   30.9205   3.1611   0.3168  0.1832   -5.5277    28.5525
#
#    fM3Trans_n  fAlpha_n   fDist_n class
# 0     -8.2027   40.0920   81.8828     g
# 1     -9.9574    6.3609  205.2610     g
# 2    -45.2160   76.9600  256.7880     g
# 3     -7.1513   10.4490  116.7370     g
# 4     21.8393    4.6480  356.4620     g

# %%
data_frame_edited['class'] = data_frame_edited['class'].replace({'g': 0, 'h': 1})

# %%
data_frame_edited.head()
# Out:
#    fLength_n  fWidth_n  fSize_n  fConc_n  fConc1   fAsym_n  fM3Long_n  \
# 0    28.7967   16.0021   2.6449   0.3918  0.1982   27.7004    22.0110
# 1    31.6036   11.7235   2.5185   0.5303  0.3773   26.2722    23.8238
# 2   162.0520  136.0310   4.0612   0.0374  0.0187  116.7410   -64.8580
# 3    23.8172    9.5728   2.3385   0.6147  0.3922   27.2107    -6.4633
# 4    75.1362   30.9205   3.1611   0.3168  0.1832   -5.5277    28.5525
#
#    fM3Trans_n  fAlpha_n   fDist_n  class
# 0     -8.2027   40.0920   81.8828      0
# 1     -9.9574    6.3609  205.2610      0
# 2    -45.2160   76.9600  256.7880      0
# 3     -7.1513   10.4490  116.7370      0
# 4     21.8393    4.6480  356.4620      0

# %% [markdown]
# ### Normalize and replace

# %%
def add_normalized_column(data_frame_edited, my_array, my_column):
    # Normalize the array
    my_array_normal = (my_array - np.min(my_array)) / (np.max(my_array) - np.min(my_array))
    # Create a DataFrame with the normalized array
    my_data_frame = pd.DataFrame(my_array_normal, columns=my_column)
    # Add the normalized column to the original DataFrame
    data_frame_edited[my_column] = my_data_frame[my_column]

# %%
add_normalized_column(data_frame_edited, data_frame_edited.iloc[:, 0:1].values, ['fLength_n'])
add_normalized_column(data_frame_edited, data_frame_edited.iloc[:, 1:2].values, ['fWidth_n'])
add_normalized_column(data_frame_edited, data_frame_edited.iloc[:, 2:3].values, ['fSize_n'])
add_normalized_column(data_frame_edited, data_frame_edited.iloc[:, 3:4].values, ['fConc_n'])
add_normalized_column(data_frame_edited, data_frame_edited.iloc[:, 6:7].values, ['fAsym_n'])
add_normalized_column(data_frame_edited, data_frame_edited.iloc[:, 7:8].values, ['fM3Long_n'])
add_normalized_column(data_frame_edited, data_frame_edited.iloc[:, 8:9].values, ['fM3Trans_n'])
add_normalized_column(data_frame_edited, data_frame_edited.iloc[:, 8:9].values, ['fAlpha_n'])
add_normalized_column(data_frame_edited, data_frame_edited.iloc[:, 9:10].values, ['fDist_n'])

# %%
data_frame_edited
# Out:
#        fLength_n  fWidth_n   fSize_n   fConc_n  fConc1   fAsym_n  fM3Long_n  \
# 0       0.074306  0.062415  0.208043  0.430390  0.1982  0.620576   0.512493
# 1       0.082815  0.045727  0.170668  0.587794  0.3773  0.623756   0.507944
# 2       0.478241  0.530579  0.626818  0.027617  0.0187  0.468201   0.416540
# 3       0.059212  0.037338  0.117445  0.683714  0.3922  0.570630   0.515219
# 4       0.214774  0.120603  0.360674  0.345153  0.1832  0.632050   0.590373
# ...          ...       ...       ...       ...     ...       ...        ...
# 19015   0.051838  0.042581  0.199527  0.650756  0.3934  0.602182   0.541215
# 19016   0.074757  0.026141  0.096363  0.593249  0.2784  0.605095   0.526076
# 19017   0.215712  0.185389  0.445594  0.146153  0.0549  0.653983   0.509218
# 19018   0.352326  0.299950  0.606919  0.092397  0.0683  0.417922   0.368263
# 19019   0.554415  0.206728  0.374926  0.311967  0.1539  0.286483   0.615354
#
#        fM3Trans_n  fAlpha_n   fDist_n  class
# 0        0.445467  0.445467  0.163066      0
# 1        0.070677  0.070677  0.412679      0
# 2        0.855111  0.855111  0.516926      0
# 3        0.116100  0.116100  0.233582      0
# 4        0.051644  0.051644  0.718582      0
# ...           ...       ...       ...    ...
# 19015    0.026921  0.026921  0.213530      1
# 19016    0.964417  0.964417  0.498046      1
# 19017    0.336652  0.336652  0.516377      1
# 19018    0.940971  0.940971  0.823491      1
# 19019    0.585900  0.585900  0.548344      1
#
# [19020 rows x 11 columns]

# %% [markdown]
# ## Feature extraction

# %%
corr_matrix = data_frame_edited.corr()

# %%
corr_matrix
# Out:
#             fLength_n  fWidth_n   fSize_n   fConc_n    fConc1   fAsym_n  \
# fLength_n    1.000000  0.770512  0.702454 -0.630999 -0.598145 -0.119747
# fWidth_n     0.770512  1.000000  0.717517 -0.609779 -0.581141 -0.176234
# fSize_n      0.702454  0.717517  1.000000 -0.850850 -0.808835  0.095157
# fConc_n     -0.630999 -0.609779 -0.850850  1.000000  0.976412 -0.121899
# fConc1      -0.598145 -0.581141 -0.808835  0.976412  1.000000 -0.118769
# fAsym_n     -0.119747 -0.176234  0.095157 -0.121899 -0.118769  1.000000
# fM3Long_n    0.013389  0.039744  0.015455 -0.011294 -0.010966 -0.017197
# fM3Trans_n  -0.008777  0.066061 -0.186675  0.235272  0.229799 -0.186275
# fAlpha_n    -0.008777  0.066061 -0.186675  0.235272  0.229799 -0.186275
# fDist_n      0.418466  0.336816  0.437041 -0.328332 -0.304625  0.037025
# class        0.307572  0.265596  0.117795 -0.024615 -0.004797 -0.193409
#
#             fM3Long_n  fM3Trans_n  fAlpha_n   fDist_n     class
# fLength_n    0.013389   -0.008777 -0.008777  0.418466  0.307572
# fWidth_n     0.039744    0.066061  0.066061  0.336816  0.265596
# fSize_n      0.015455   -0.186675 -0.186675  0.437041  0.117795
# fConc_n     -0.011294    0.235272  0.235272 -0.328332 -0.024615
# fConc1      -0.010966    0.229799  0.229799 -0.304625 -0.004797
# fAsym_n     -0.017197   -0.186275 -0.186275  0.037025 -0.193409
# fM3Long_n    1.000000    0.004659  0.004659  0.011427  0.003837
# fM3Trans_n   0.004659    1.000000  1.000000 -0.220556  0.460979
# fAlpha_n     0.004659    1.000000  1.000000 -0.220556  0.460979
# fDist_n      0.011427   -0.220556 -0.220556  1.000000  0.065203
# class        0.003837    0.460979  0.460979  0.065203  1.000000

# %%
from sklearn.decomposition import PCA

x_param = data_frame_edited.drop('class', axis=1)
y_param = data_frame_edited['class']

pca = PCA(n_components=5)  # Choose the desired number of principal components
x_param_pca = pca.fit_transform(x_param)

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
rfe = RFE(model, n_features_to_select=5)  # Choose the desired number of features
x_param_rfe = rfe.fit_transform(x_param, y_param)

# %%
from sklearn.feature_selection import mutual_info_classif

mutual_info = mutual_info_classif(x_param, y_param)
mutual_info_df = pd.DataFrame({'feature': x_param.columns, 'mutual_info': mutual_info})
mutual_info_df = mutual_info_df.sort_values('mutual_info', ascending=False)

# %%
mutual_info_df
# Out:
#       feature  mutual_info
# 8    fAlpha_n     0.124349
# 7  fM3Trans_n     0.123909
# 1    fWidth_n     0.096706
# 0   fLength_n     0.085565
# 5     fAsym_n     0.077542
# 6   fM3Long_n     0.068664
# 2     fSize_n     0.053159
# 3     fConc_n     0.022911
# 4      fConc1     0.014590
# 9     fDist_n     0.013381

# %%
column_set_01 = ['fAlpha_n']
column_set_02 = ['fAlpha_n', 'fM3Trans_n']
column_set_03 = ['fAlpha_n', 'fM3Trans_n', 'fWidth_n']
column_set_04 = ['fAlpha_n', 'fM3Trans_n', 'fWidth_n', 'fLength_n']
column_set_05 = ['fAlpha_n', 'fM3Trans_n', 'fWidth_n', 'fLength_n', 'fAsym_n']
column_set_06 = ['fAlpha_n', 'fM3Trans_n', 'fWidth_n', 'fLength_n', 'fAsym_n', 'fM3Long_n']
column_set_07 = ['fAlpha_n', 'fM3Trans_n', 'fWidth_n', 'fLength_n', 'fAsym_n', 'fM3Long_n', 'fSize_n']
column_set_08 = ['fAlpha_n', 'fM3Trans_n', 'fWidth_n', 'fLength_n', 'fAsym_n', 'fM3Long_n', 'fSize_n', 'fConc_n']
column_set_09 = ['fAlpha_n', 'fM3Trans_n', 'fWidth_n', 'fLength_n', 'fAsym_n', 'fM3Long_n', 'fSize_n', 'fConc_n', 'fConc1']
column_set_10 = ['fAlpha_n', 'fM3Trans_n', 'fWidth_n', 'fLength_n', 'fAsym_n', 'fM3Long_n', 'fSize_n', 'fConc_n', 'fConc1', 'fDist_n']

# %%
my_lr = 0.01

# %%
my_e = 100

# %% [markdown]
# ## 'model_03' details

# %%
columns_to_have_in_x0 = column_set_06
x0 = data_frame_edited[columns_to_have_in_x0]

# %%
x_var_count = len(columns_to_have_in_x0)

# %%
columns_to_have_in_y = ['class']
y = data_frame_edited[columns_to_have_in_y]

# %%
x0_train, x0_test, y_train, y_test = train_test_split(x0 , y, test_size=0.25, random_state=42)

# %%
x0_train_tensor = tf.convert_to_tensor(x0_train)
x0_test_tensor = tf.convert_to_tensor(x0_test)

# %%
y_train_tensor = tf.convert_to_tensor(y_train)
y_test_tensor = tf.convert_to_tensor(y_test)

# %%
model_03 = None

# %%
# Define the input shape for n independent variables
input_shape = (x_var_count,)  # Each input sample has n features

# Set the random seed
tf.random.set_seed(42)

# Create the model
model_03 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=input_shape),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(12, activation='relu'),
    tf.keras.layers.Dropout(0.01),
    tf.keras.layers.Dense(12, activation='relu'),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
model_03.compile(
                  loss=tf.keras.losses.BinaryCrossentropy(),
                  optimizer=tf.keras.optimizers.Adam(learning_rate=my_lr),
                  metrics=["accuracy"]
                )

# Fit the model
history_03 = model_03.fit(x0_train_tensor, y_train_tensor, epochs=my_e)
# Out:
# Epoch 1/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7230 - loss: 0.5501
# Epoch 2/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7921 - loss: 0.4488
# Epoch 3/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8020 - loss: 0.4366
# Epoch 4/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8036 - loss: 0.4324
# Epoch 5/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8041 - loss: 0.4282
# Epoch 6/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8069 - loss: 0.4257
# Epoch 7/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8092 - loss: 0.4236
# Epoch 8/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8090 - loss: 0.4234
# Epoch 9/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8106 - loss: 0.4219
# Epoch 10/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8107 - loss: 0.4213
# Epoch 11/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8117 - loss: 0.4210
# Epoch 12/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8118 - loss: 0.4187
# Epoch 13/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8129 - loss: 0.4194
# Epoch 14/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8139 - loss: 0.4187
# Epoch 15/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8145 - loss: 0.4174
# Epoch 16/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8161 - loss: 0.4167
# Epoch 17/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8151 - loss: 0.4182
# Epoch 18/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8173 - loss: 0.4162
# Epoch 19/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8161 - loss: 0.4160
# Epoch 20/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8162 - loss: 0.4159
# Epoch 21/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8175 - loss: 0.4159
# Epoch 22/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8171 - loss: 0.4155
# Epoch 23/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8199 - loss: 0.4149
# Epoch 24/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8184 - loss: 0.4147
# Epoch 25/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8199 - loss: 0.4138
# Epoch 26/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8178 - loss: 0.4149
# Epoch 27/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8208 - loss: 0.4144
# Epoch 28/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8194 - loss: 0.4148
# Epoch 29/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8200 - loss: 0.4131
# Epoch 30/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8201 - loss: 0.4136
# Epoch 31/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8192 - loss: 0.4140
# Epoch 32/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8209 - loss: 0.4121
# Epoch 33/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8184 - loss: 0.4136
# Epoch 34/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8196 - loss: 0.4119
# Epoch 35/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8196 - loss: 0.4120
# Epoch 36/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8208 - loss: 0.4124
# Epoch 37/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8200 - loss: 0.4127
# Epoch 38/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8211 - loss: 0.4122
# Epoch 39/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8208 - loss: 0.4117
# Epoch 40/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8205 - loss: 0.4123
# Epoch 41/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8202 - loss: 0.4115
# Epoch 42/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8204 - loss: 0.4121
# Epoch 43/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8185 - loss: 0.4128
# Epoch 44/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8194 - loss: 0.4127
# Epoch 45/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8196 - loss: 0.4122
# Epoch 46/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8196 - loss: 0.4130
# Epoch 47/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8216 - loss: 0.4112
# Epoch 48/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8192 - loss: 0.4122
# Epoch 49/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8199 - loss: 0.4117
# Epoch 50/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8200 - loss: 0.4116
# Epoch 51/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8201 - loss: 0.4115
# Epoch 52/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8188 - loss: 0.4120
# Epoch 53/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8202 - loss: 0.4111
# Epoch 54/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8186 - loss: 0.4120
# Epoch 55/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8195 - loss: 0.4113
# Epoch 56/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8199 - loss: 0.4121
# Epoch 57/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8192 - loss: 0.4124
# Epoch 58/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8182 - loss: 0.4124
# Epoch 59/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8187 - loss: 0.4124
# Epoch 60/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8197 - loss: 0.4120
# Epoch 61/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8206 - loss: 0.4125
# Epoch 62/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8205 - loss: 0.4110
# Epoch 63/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8206 - loss: 0.4119
# Epoch 64/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8205 - loss: 0.4114
# Epoch 65/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8203 - loss: 0.4108
# Epoch 66/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8201 - loss: 0.4112
# Epoch 67/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8208 - loss: 0.4115
# Epoch 68/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8197 - loss: 0.4116
# Epoch 69/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8204 - loss: 0.4106
# Epoch 70/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8189 - loss: 0.4116
# Epoch 71/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8194 - loss: 0.4109
# Epoch 72/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8195 - loss: 0.4109
# Epoch 73/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8200 - loss: 0.4108
# Epoch 74/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8201 - loss: 0.4125
# Epoch 75/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8199 - loss: 0.4108
# Epoch 76/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8204 - loss: 0.4103
# Epoch 77/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8194 - loss: 0.4110
# Epoch 78/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8212 - loss: 0.4109
# Epoch 79/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8201 - loss: 0.4110
# Epoch 80/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8190 - loss: 0.4120
# Epoch 81/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8196 - loss: 0.4115
# Epoch 82/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8198 - loss: 0.4116
# Epoch 83/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8220 - loss: 0.4119
# Epoch 84/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8192 - loss: 0.4124
# Epoch 85/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8196 - loss: 0.4107
# Epoch 86/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8204 - loss: 0.4112
# Epoch 87/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8205 - loss: 0.4111
# Epoch 88/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8199 - loss: 0.4111
# Epoch 89/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8184 - loss: 0.4119
# Epoch 90/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8207 - loss: 0.4106
# Epoch 91/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8196 - loss: 0.4120
# Epoch 92/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8187 - loss: 0.4118
# Epoch 93/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8198 - loss: 0.4109
# Epoch 94/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8217 - loss: 0.4113
# Epoch 95/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8213 - loss: 0.4110
# Epoch 96/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8205 - loss: 0.4110
# Epoch 97/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8213 - loss: 0.4114
# Epoch 98/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8223 - loss: 0.4118
# Epoch 99/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8207 - loss: 0.4116
# Epoch 100/100
# 446/446 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8208 - loss: 0.4117

# %%
# Evaluate model_03 on the test dataset
model_03.evaluate(x0_test_tensor, y_test_tensor)
# Out:
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8243 - loss: 0.4066
# [0.4087980091571808, 0.8235541582107544]
